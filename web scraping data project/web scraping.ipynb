# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = {"User-Agent": "Mozilla/5.0"}

# %%
for i in range(1, 10):
    url = f"https://www.flipkart.com/mobile-phones-sasa-lele-2026-ab-inline-at-store"
    print(url)

    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text,"lxml")
# Out:
# https://www.flipkart.com/mobile-phones-sasa-lele-2026-ab-inline-at-store
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 url = f"https://www.flipkart.com/mobile-phones-sasa-lele-2026-ab-inline-at-store"
#       3 print(url)
# ----> 5 r = requests.get(url, headers=headers)
#       6 soup = BeautifulSoup(r.text,"lxml")
#
# NameError: name 'requests' is not defined
